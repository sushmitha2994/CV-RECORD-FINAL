# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt

# 1. Start
print("Training GAN for handwritten digits...")

# 2. Load and preprocess data
(x_train, _), (_, _) = tf.keras.datasets.mnist.load_data()
x_train = x_train / 127.5 - 1.0  # Normalize to [-1, 1]
x_train = x_train.reshape(-1, 784).astype(np.float32)

# 3. Create generator model
def build_generator():
    model = models.Sequential([
        layers.Dense(256, input_dim=100),
        layers.LeakyReLU(0.2),
        layers.Dense(512),
        layers.LeakyReLU(0.2),
        layers.Dense(1024),
        layers.LeakyReLU(0.2),
        layers.Dense(784, activation='tanh')
    ])
    return model

# 4. Create discriminator model
def build_discriminator():
    model = models.Sequential([
        layers.Dense(1024, input_dim=784),
        layers.LeakyReLU(0.2),
        layers.Dropout(0.3),
        layers.Dense(512),
        layers.LeakyReLU(0.2),
        layers.Dropout(0.3),
        layers.Dense(256),
        layers.LeakyReLU(0.2),
        layers.Dropout(0.3),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

# Build models
generator = build_generator()
discriminator = build_discriminator()

# Compile discriminator
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 5. Combine generator and discriminator into GAN
z = layers.Input(shape=(100,))
img = generator(z)
discriminator.trainable = False
validity = discriminator(img)
gan = models.Model(z, validity)
gan.compile(loss='binary_crossentropy', optimizer='adam')

# 6. Training the GAN
def train_gan(epochs, batch_size=128):
    for epoch in range(epochs):
        # Train discriminator
        idx = np.random.randint(0, x_train.shape[0], batch_size)
        real_imgs = x_train[idx]

        noise = np.random.normal(0, 1, (batch_size, 100))
        fake_imgs = generator.predict(noise)

        d_loss_real = discriminator.train_on_batch(real_imgs, np.ones((batch_size, 1)))
        d_loss_fake = discriminator.train_on_batch(fake_imgs, np.zeros((batch_size, 1)))
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train generator
        noise = np.random.normal(0, 1, (batch_size, 100))
        g_loss = gan.train_on_batch(noise, np.ones((batch_size, 1)))

        # Print progress
        print(f"Epoch {epoch+1}/{epochs} [D loss: {d_loss[0]:.4f}, acc: {100*d_loss[1]:.2f}%] [G loss: {g_loss:.4f}]")

        # Plot generated images every 20 epochs
        if (epoch + 1) % 20 == 0:
            plot_generated_images(epoch + 1, generator)

# Plotting function
def plot_generated_images(epoch, generator, examples=16, dim=(4, 4)):
    noise = np.random.normal(0, 1, (examples, 100))
    gen_imgs = generator.predict(noise)
    gen_imgs = 0.5 * gen_imgs + 0.5  # Scale back to [0,1]

    plt.figure(figsize=(4, 4))
    for i in range(examples):
        plt.subplot(dim[0], dim[1], i+1)
        plt.imshow(gen_imgs[i].reshape(28, 28), cmap='gray')
        plt.axis('off')
    plt.suptitle(f"Generated digits at epoch {epoch}")
    plt.tight_layout()
    plt.show()

# Start training
train_gan(epochs=100, batch_size=128)

# 7. End
print("GAN training completed.")
# Out:
# Training GAN for handwritten digits...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py:82: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# Epoch 1/100 [D loss: 0.5986, acc: 64.06%] [G loss: 0.6834]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 2/100 [D loss: 0.7567, acc: 50.59%] [G loss: 0.4397]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch 3/100 [D loss: 1.0346, acc: 43.83%] [G loss: 0.3065]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 4/100 [D loss: 1.4156, acc: 40.49%] [G loss: 0.2321]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 5/100 [D loss: 1.8289, acc: 39.75%] [G loss: 0.1861]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 6/100 [D loss: 2.2249, acc: 38.73%] [G loss: 0.1552]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Epoch 7/100 [D loss: 2.5926, acc: 37.67%] [G loss: 0.1331]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 8/100 [D loss: 2.9199, acc: 37.19%] [G loss: 0.1165]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 9/100 [D loss: 3.1885, acc: 37.31%] [G loss: 0.1035]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 10/100 [D loss: 3.4269, acc: 37.04%] [G loss: 0.0932]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 11/100 [D loss: 3.6308, acc: 36.72%] [G loss: 0.0847]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 12/100 [D loss: 3.8059, acc: 36.69%] [G loss: 0.0777]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 13/100 [D loss: 3.9586, acc: 36.41%] [G loss: 0.0717]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 14/100 [D loss: 4.0916, acc: 36.32%] [G loss: 0.0666]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 15/100 [D loss: 4.2093, acc: 36.24%] [G loss: 0.0622]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Epoch 16/100 [D loss: 4.3142, acc: 36.07%] [G loss: 0.0583]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Epoch 17/100 [D loss: 4.4074, acc: 36.02%] [G loss: 0.0549]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 18/100 [D loss: 4.4882, acc: 36.03%] [G loss: 0.0518]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch 19/100 [D loss: 4.5605, acc: 35.96%] [G loss: 0.0491]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 20/100 [D loss: 4.6290, acc: 35.96%] [G loss: 0.0466]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch 21/100 [D loss: 4.6918, acc: 35.96%] [G loss: 0.0444]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 22/100 [D loss: 4.7458, acc: 36.00%] [G loss: 0.0424]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 23/100 [D loss: 4.7934, acc: 35.94%] [G loss: 0.0406]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 24/100 [D loss: 4.8387, acc: 35.91%] [G loss: 0.0389]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch 25/100 [D loss: 4.8843, acc: 35.93%] [G loss: 0.0373]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 26/100 [D loss: 4.9280, acc: 35.96%] [G loss: 0.0359]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 27/100 [D loss: 4.9693, acc: 35.84%] [G loss: 0.0346]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 28/100 [D loss: 5.0087, acc: 35.81%] [G loss: 0.0333]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 29/100 [D loss: 5.0434, acc: 35.82%] [G loss: 0.0322]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 30/100 [D loss: 5.0733, acc: 35.80%] [G loss: 0.0311]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch 31/100 [D loss: 5.1015, acc: 35.67%] [G loss: 0.0301]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 32/100 [D loss: 5.1284, acc: 35.66%] [G loss: 0.0292]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 33/100 [D loss: 5.1541, acc: 35.70%] [G loss: 0.0283]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 34/100 [D loss: 5.1783, acc: 35.56%] [G loss: 0.0275]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 35/100 [D loss: 5.2002, acc: 35.50%] [G loss: 0.0267]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 36/100 [D loss: 5.2233, acc: 35.47%] [G loss: 0.0259]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 37/100 [D loss: 5.2444, acc: 35.46%] [G loss: 0.0252]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 38/100 [D loss: 5.2638, acc: 35.43%] [G loss: 0.0246]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 39/100 [D loss: 5.2809, acc: 35.43%] [G loss: 0.0239]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 40/100 [D loss: 5.2972, acc: 35.47%] [G loss: 0.0233]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 41/100 [D loss: 5.3127, acc: 35.46%] [G loss: 0.0228]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 42/100 [D loss: 5.3271, acc: 35.41%] [G loss: 0.0222]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 43/100 [D loss: 5.3410, acc: 35.34%] [G loss: 0.0217]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 44/100 [D loss: 5.3552, acc: 35.39%] [G loss: 0.0212]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 45/100 [D loss: 5.3690, acc: 35.32%] [G loss: 0.0208]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch 46/100 [D loss: 5.3806, acc: 35.28%] [G loss: 0.0203]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 47/100 [D loss: 5.3940, acc: 35.27%] [G loss: 0.0199]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 48/100 [D loss: 5.4072, acc: 35.31%] [G loss: 0.0195]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 49/100 [D loss: 5.4196, acc: 35.30%] [G loss: 0.0191]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 50/100 [D loss: 5.4327, acc: 35.26%] [G loss: 0.0187]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 51/100 [D loss: 5.4457, acc: 35.18%] [G loss: 0.0183]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 52/100 [D loss: 5.4568, acc: 35.19%] [G loss: 0.0180]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 53/100 [D loss: 5.4660, acc: 35.21%] [G loss: 0.0176]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 54/100 [D loss: 5.4775, acc: 35.23%] [G loss: 0.0173]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 55/100 [D loss: 5.4889, acc: 35.23%] [G loss: 0.0170]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 56/100 [D loss: 5.5004, acc: 35.20%] [G loss: 0.0167]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 57/100 [D loss: 5.5123, acc: 35.15%] [G loss: 0.0164]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 58/100 [D loss: 5.5223, acc: 35.13%] [G loss: 0.0161]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 59/100 [D loss: 5.5316, acc: 35.09%] [G loss: 0.0158]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 60/100 [D loss: 5.5405, acc: 35.11%] [G loss: 0.0156]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 61/100 [D loss: 5.5487, acc: 35.13%] [G loss: 0.0153]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 62/100 [D loss: 5.5568, acc: 35.12%] [G loss: 0.0151]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 63/100 [D loss: 5.5648, acc: 35.11%] [G loss: 0.0148]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 64/100 [D loss: 5.5727, acc: 35.13%] [G loss: 0.0146]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 65/100 [D loss: 5.5806, acc: 35.10%] [G loss: 0.0144]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch 66/100 [D loss: 5.5883, acc: 35.03%] [G loss: 0.0142]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 67/100 [D loss: 5.5966, acc: 35.03%] [G loss: 0.0140]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 68/100 [D loss: 5.6043, acc: 35.02%] [G loss: 0.0138]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 69/100 [D loss: 5.6100, acc: 35.01%] [G loss: 0.0136]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch 70/100 [D loss: 5.6143, acc: 35.00%] [G loss: 0.0134]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 71/100 [D loss: 5.6192, acc: 35.04%] [G loss: 0.0132]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 72/100 [D loss: 5.6260, acc: 35.02%] [G loss: 0.0130]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Epoch 73/100 [D loss: 5.6326, acc: 35.00%] [G loss: 0.0128]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 74/100 [D loss: 5.6394, acc: 34.99%] [G loss: 0.0126]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 75/100 [D loss: 5.6453, acc: 34.98%] [G loss: 0.0125]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Epoch 76/100 [D loss: 5.6501, acc: 34.96%] [G loss: 0.0123]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 77/100 [D loss: 5.6562, acc: 34.95%] [G loss: 0.0122]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 78/100 [D loss: 5.6628, acc: 34.91%] [G loss: 0.0120]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 79/100 [D loss: 5.6682, acc: 34.86%] [G loss: 0.0118]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 80/100 [D loss: 5.6722, acc: 34.89%] [G loss: 0.0117]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 81/100 [D loss: 5.6770, acc: 34.88%] [G loss: 0.0116]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 82/100 [D loss: 5.6814, acc: 34.89%] [G loss: 0.0114]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 83/100 [D loss: 5.6864, acc: 34.90%] [G loss: 0.0113]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 84/100 [D loss: 5.6931, acc: 34.87%] [G loss: 0.0111]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 85/100 [D loss: 5.6995, acc: 34.86%] [G loss: 0.0110]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 86/100 [D loss: 5.7044, acc: 34.86%] [G loss: 0.0109]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 87/100 [D loss: 5.7088, acc: 34.88%] [G loss: 0.0108]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 88/100 [D loss: 5.7132, acc: 34.88%] [G loss: 0.0106]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 89/100 [D loss: 5.7178, acc: 34.86%] [G loss: 0.0105]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 90/100 [D loss: 5.7222, acc: 34.85%] [G loss: 0.0104]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 91/100 [D loss: 5.7256, acc: 34.86%] [G loss: 0.0103]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 92/100 [D loss: 5.7298, acc: 34.83%] [G loss: 0.0102]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 93/100 [D loss: 5.7340, acc: 34.84%] [G loss: 0.0101]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 94/100 [D loss: 5.7387, acc: 34.85%] [G loss: 0.0100]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 95/100 [D loss: 5.7438, acc: 34.87%] [G loss: 0.0099]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Epoch 96/100 [D loss: 5.7483, acc: 34.88%] [G loss: 0.0098]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 97/100 [D loss: 5.7529, acc: 34.86%] [G loss: 0.0097]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Epoch 98/100 [D loss: 5.7577, acc: 34.84%] [G loss: 0.0096]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 99/100 [D loss: 5.7623, acc: 34.83%] [G loss: 0.0095]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Epoch 100/100 [D loss: 5.7658, acc: 34.79%] [G loss: 0.0094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# GAN training completed.
